# %%
#End Date: 01/12/2021     CONTINUOUS ASSESSMENT 2       Regno:E7321013
#                                                       Name:Prem KUmar K S
#1.
class Error(Exception):
    pass

class NOgradeError(Error):
    pass

class Subject_list(object):
    
    class_list = []
    
    def __init__(self, test_grades, test_marks):
        self.test_grades = test_grades
        self.test_marks = test_marks
        
    def find_average(self, test_marks):
        try:
            if test_marks == []:
                raise NOgradeError("NO GRADE FOR A STUDENT")
        except NOgradeError:
            print("NO GRADE FOR A STUDENT.")
        else:
            avege = sum(test_marks) / len(test_marks)
            return avege
    
    def displayer(self):
#         Subject_list.find_average(self, test_marks)
        Subject_list.class_list.append(self.test_grades)
        print("Class List = ", Subject_list.class_list)  
        
ini = 0
names = []
marks = []
test_grades = []
while ini == 0:
    dummy = []
    names = list(map(str, input("Enter the name: ").split()))
    marks = list(map(float, input("Enter the marks: ").split()))
    test_names = [n for n in names] 
    test_marks = [m for m in marks]
    dummy.append(test_names)
    dummy.append(test_marks)
    averager = Subject_list.find_average(test_grades, test_marks)
    dummy.append(averager)
    test_grades.append(dummy)
    mark_list = Subject_list(test_grades, test_marks)
    ent = int(input("Enter 0 if you want to add more marklists if not enter 1: "))
    if ent != 0:
        ini += 1

mark_list.displayer()
# Out:
# Enter the name: Peter Parker
# Enter the marks: 80 70 85
# Enter 0 if you want to add more marklists if not enter 1: 0
# Enter the name: Bruce Wayne
# Enter the marks: 100 80 74
# Enter 0 if you want to add more marklists if not enter 1: 0
# Enter the name: Captain America
# Enter the marks:  80 100 96
# Enter 0 if you want to add more marklists if not enter 1: 0
# Enter the name: Deadpool
# Enter the marks:
# NO GRADE FOR A STUDENT.
# Enter 0 if you want to add more marklists if not enter 1: 1
# Class List =  [[[['Peter', 'Parker'], [80.0, 70.0, 85.0], 78.33333333333333], [['Bruce', 'Wayne'], [100.0, 80.0, 74.0], 84.66666666666667], [['Captain', 'America'], [80.0, 100.0, 96.0], 92.0], [['Deadpool'], [], None]]]

# %%
#2.
class Complex:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def __sub__(self, other):
        return self.a - other.a, self.b - other.b
        
class negative:
    def __init__(self, a):
        self.a = a
                
    def __neg__(self):
         return -self.a
    
print("""Choose the options:
                1. Difference between two complex numbers
                2. Negative of a number.""")


val = 0
while val == 0:
    option = int(input("Choose the option: "))
    if option == 1:
        obj1 = Complex(4, 5)
        obj2 = Complex(1, 2)
        e = obj1 - obj2
        print(e)
    
    elif option == 2:
        value = int(input("Enter the value: "))
        negs = negative(value)
        print(-negs)
    
    else:
        print("Something went wrong!")
    
    val = int(input("Enter 0 to continue the process or 1 to exit. "))
# Out:
# Choose the options:
#                 1. Difference between two complex numbers
#                 2. Negative of a number.
# Choose the option: 1
# (3, 3)
# Enter 0 to continue the process or 1 to exit. 0
# Choose the option: 2
# Enter the value: 25
# -25
# Enter 0 to continue the process or 1 to exit. 1

# %%
#3.
import re

def is_allowed_specific_char(Input_str):
    expected_string = r'[a-zA-z]+'
    print(re.match(expected_string, Input_str, re.IGNORECASE))

Input_str = input("Enter the string: ")
is_allowed_specific_char(Input_str)
# Out:
# Enter the string: fvsebte4546832453&*%
# <re.Match object; span=(0, 7), match='fvsebte'>

# %%
#4
class Error(Exception):
    pass

class ZeroBalanceError(Error):
    pass



class Budget(object):
    
    budgdict = [{"category": "Food", "amount": 0},
           {"category": "Clothing", "amount": 0},
           {"category": "Entertainment", "amount": 0}]
    
    def init(self):
        pass
    
    def deposit_withdraw(self):
        print("Welcome!")
        print("""Choose the category
                            1.Food
                            2.Clothing
                            3.Entertainment""")
        loopval = 0
        while loopval == 0:
            cat_choice = int(input("Enter your choice: "))
            if cat_choice >= 4:
                print("OOPS! Invalid choice ")
            else:
                if cat_choice == 1:
                    foodie = 0
                    while foodie == 0:
                        class Food(Budget):
                            print("------------------------------------")
                            print("Deposit: ")
                            print("Category Name: ", Budget.budgdict[0]["category"])
                            print("Available balance: ", Budget.budgdict[0]["amount"])
                            amountd = int(input("Enter the amount to deposit: "))
                            Budget.budgdict[0]["amount"] += amountd
                            print("------------------------------------")
                            print("Withdraw: ")
                            print("Category Name: ", Budget.budgdict[0]["category"])
                            print("Available balance: ", Budget.budgdict[0]["amount"])
                            amountw = int(input("Enter the amount to withdraw: "))
                            try:
                                if amountw > Budget.budgdict[0]["amount"]:
                                    raise ZeroBalanceError("You have less balance in your account.")
                            except ZeroBalanceError:
                                print("You have less balance in your account.")
                            else:
                                Budget.budgdict[0]["amount"] = Budget.budgdict[0]["amount"] - amountw
                            print("------------------------------------")
                            print("You want to continue to deposit and withdraw money from Food?")
                        foodie = int(input("If 'YES' Enter 0 or Enter 1"))
                elif cat_choice == 2:
                    cloth = 0
                    while cloth == 0:
                        class Clothes(Budget):
                            print("------------------------------------")
                            print("Deposit: ")
                            print("Category Name: ", Budget.budgdict[1]["category"])
                            print("Available balance: ", Budget.budgdict[1]["amount"])
                            amountd = int(input("Enter the amount to deposit: "))
                            Budget.budgdict[1]["amount"] += amountd
                            print("------------------------------------")
                            print("Withdraw: ")
                            print("Category Name: ", Budget.budgdict[1]["category"])
                            print("Available balance: ", Budget.budgdict[1]["amount"])
                            amountw = int(input("Enter the amount to withdraw: "))
                            try:
                                if amountw > Budget.budgdict[1]["amount"]:
                                    raise ZeroBalanceError("You have less balance in your account.")
                            except ZeroBalanceError:
                                print("You have less balance in your account.")
                            else:
                                Budget.budgdict[1]["amount"] = Budget.budgdict[1]["amount"] - amountw
                            print("------------------------------------")
                            print("You want to continue to deposit and withdraw money from Clothes?")
                        cloth = int(input("If 'YES' Enter 0 or Enter 1"))
                elif cat_choice == 3:
                    entertain = 0
                    while entertain == 0:
                        class Entertainment(Budget):
                            print("------------------------------------")
                            print("Deposit: ")
                            print("Category Name: ", Budget.budgdict[2]["category"])
                            print("Available balance: ", Budget.budgdict[2]["amount"])
                            amountd = int(input("Enter the amount to deposit: "))
                            Budget.budgdict[2]["amount"] += amountd
                            print("------------------------------------")
                            print("Withdraw: ")
                            print("Category Name: ", Budget.budgdict[2]["category"])
                            print("Available balance: ", Budget.budgdict[2]["amount"])
                            amountw = int(input("Enter the amount to withdraw: "))
                            try:
                                if amountw > Budget.budgdict[2]["amount"]:
                                    raise ZeroBalanceError("You have less balance in your account.")
                            except ZeroBalanceError:
                                print("You have less balance in your account.")
                            else:
                                Budget.budgdict[2]["amount"] = Budget.budgdict[2]["amount"] - amountw
                            print("------------------------------------")
                            print("You want to continue to deposit and withdraw money from Entertainment?")
                        entertain = int(input("If 'YES' Enter 0 or Enter 1"))
                loopval = int(input("Enter 0 to surf through other categories or enter 1: "))
                
    def tranferer(self):
        print("------------------------------------")
        print("Welcome Again!")
        print("""Transfer amount from
                            1.Food
                            2.Clothing
                            3.Entertainment""")
        category_from = int(input())
        print("------------------------------------")
        print("""Transfer amount to
                            1.Food
                            2.Clothing
                            3.Entertainment""")
        category_to = int(input())
        print("Available balance in ",Budget.budgdict[category_from - 1])
        print("Available balance in ",Budget.budgdict[category_to - 1])
        excepts = 0
        while excepts == 0:
            tranfer_amount = int(input("Enter the amount to tranfer"))
            if category_from == category_to:
                print("You can't transfer the amount to the same category")
            else:
                try:
                    if tranfer_amount > Budget.budgdict[category_from - 1]["amount"]:
                        raise ZeroBalanceError("Enter a lesser amount.")
                except ZeroBalanceError:
                    print("Enter a lesser amount.")
                else:
                    Budget.budgdict[category_from - 1]["amount"] = Budget.budgdict[category_from - 1]["amount"] - tranfer_amount 
                    Budget.budgdict[category_to - 1]["amount"] += tranfer_amount
                    excepts = 1
                        
a = Budget()
a.deposit_withdraw()
a.tranferer()
print(Budget.budgdict)
# Out:
# Welcome!
# Choose the category
#                             1.Food
#                             2.Clothing
#                             3.Entertainment
# Enter your choice: 1
# ------------------------------------
# Deposit:
# Category Name:  Food
# Available balance:  0
# Enter the amount to deposit: 1000
# ------------------------------------
# Withdraw:
# Category Name:  Food
# Available balance:  1000
# Enter the amount to withdraw: 2000
# You have less balance in your account.
# ------------------------------------
# You want to continue to deposit and withdraw money from Food?
# If 'YES' Enter 0 or Enter 11
# Enter 0 to surf through other categories or enter 1: 0
# Enter your choice: 1
# ------------------------------------
# Deposit:
# Category Name:  Food
# Available balance:  1000
# Enter the amount to deposit: 0
# ------------------------------------
# Withdraw:
# Category Name:  Food
# Available balance:  1000
# Enter the amount to withdraw: 250
# ------------------------------------
# You want to continue to deposit and withdraw money from Food?
# If 'YES' Enter 0 or Enter 11
# Enter 0 to surf through other categories or enter 1: 0
# Enter your choice: 2
# ------------------------------------
# Deposit:
# Category Name:  Clothing
# Available balance:  0
# Enter the amount to deposit: 2000
# ------------------------------------
# Withdraw:
# Category Name:  Clothing
# Available balance:  2000
# Enter the amount to withdraw: 500
# ------------------------------------
# You want to continue to deposit and withdraw money from Clothes?
# If 'YES' Enter 0 or Enter 11
# Enter 0 to surf through other categories or enter 1: 0
# Enter your choice: 3
# ------------------------------------
# Deposit:
# Category Name:  Entertainment
# Available balance:  0
# Enter the amount to deposit: 3000
# ------------------------------------
# Withdraw:
# Category Name:  Entertainment
# Available balance:  3000
# Enter the amount to withdraw: 750
# ------------------------------------
# You want to continue to deposit and withdraw money from Entertainment?
# If 'YES' Enter 0 or Enter 11
# Enter 0 to surf through other categories or enter 1: 1
# ------------------------------------
# Welcome Again!
# Transfer amount from
#                             1.Food
#                             2.Clothing
#                             3.Entertainment
# 3
# ------------------------------------
# Transfer amount to
#                             1.Food
#                             2.Clothing
#                             3.Entertainment
# 1
# Available balance in  {'category': 'Entertainment', 'amount': 2250}
# Available balance in  {'category': 'Food', 'amount': 750}
# Enter the amount to tranfer3000
# Enter a lesser amount.
# Enter the amount to tranfer250
# [{'category': 'Food', 'amount': 1000}, {'category': 'Clothing', 'amount': 1500}, {'category': 'Entertainment', 'amount': 2000}]
